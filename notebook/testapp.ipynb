# %%
import requests

# %%
res = requests.post(
    # Port 5000 for flask only
    url="http://localhost:8080/predict",
    json={
        "x": 100.0,
    }
)

# %%
res.json()
# Out:
# {'Input': 100.0, 'y': 10000.0}
